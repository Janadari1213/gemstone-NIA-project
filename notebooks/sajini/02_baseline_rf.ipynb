# %% [markdown]
# # Baseline Random Forest for Diamonds Dataset
# This notebook runs a baseline Random Forest Regressor on all features to provide a benchmark before applying Nature-Inspired Algorithms for feature selection.

# %%
import os
import sys
import json
from IPython.display import Image, display

project_root = os.path.abspath('../../')
if project_root not in sys.path:
    sys.path.append(project_root)

from src.baseline_rf_diamonds import run_baseline

# %%
# Run the baseline script
run_baseline()

# %%
# Display metrics
metrics_path = os.path.join(project_root, 'results', 'baseline_rf.json')
with open(metrics_path, 'r') as f:
    metrics = json.load(f)
    
print("Baseline Metrics:")
print(json.dumps(metrics, indent=4))

# %%
# Display Feature Importance Plot
plot_path = os.path.join(project_root, 'results', 'baseline_rf_feature_importance.png')
display(Image(filename=plot_path))
