# %% [markdown]
# # Baseline XGBoost Model
#
# This notebook runs the baseline XGBoost model script (`src/baseline_xgb_gemstone.py`) and displays the results and feature importance plot inline.

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', '..')))
# %run ../../src/baseline_xgb_gemstone.py

# %%
import json
with open('../../results/baseline_xgb.json', 'r') as f:
    metrics = json.load(f)
print("Baseline Metrics:")
print(json.dumps(metrics, indent=4))

# %%
from IPython.display import Image, display
display(Image(filename='../../results/baseline_xgb_feature_importance.png'))
