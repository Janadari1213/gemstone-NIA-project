# %% [markdown]
# # Particle Swarm Optimization (PSO) for Feature Selection
#
# This notebook runs the Binary PSO algorithm from scratch to find an optimal feature subset for the XGBoost model. The algorithm evaluates feature subsets by balancing their cross-validated $R^2$ performance against a penalty for the number of features selected.

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', '..')))

# Run the PSO script
# %run ../../src/pso_feature_selection.py

# %%
import json
with open('../../results/pso_selected_features.json', 'r') as f:
    results = json.load(f)
print("PSO Selected Features and Metrics:")
print(json.dumps(results, indent=4))

# %%
from IPython.display import Image, display
import os
if os.path.exists('../../results/pso_convergence.png'):
    display(Image(filename='../../results/pso_convergence.png'))
else:
    print('Convergence plot not found.')
