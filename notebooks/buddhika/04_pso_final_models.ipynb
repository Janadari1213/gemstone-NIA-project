# %% [markdown]
# # Final Models Evaluation (PSO Selected Features)
#
# This notebook trains and evaluates the final XGBoost and Random Forest models using only the features selected by our Binary PSO algorithm. We compare their real-world performance on the held-out test set against the baseline XGBoost model.

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', '..')))

# Run the script to train models and generate comparisons
# %run ../../src/train_pso_models.py

# %%
from IPython.display import Image, display
import os

plot_path = '../../results/pso_vs_baseline_comparison.png'
if os.path.exists(plot_path):
    display(Image(filename=plot_path))
else:
    print('Comparison plot not found.')
